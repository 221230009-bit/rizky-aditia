# %% [markdown]
# <a href="https://colab.research.google.com/github/221230009-bit/rizky-aditia/blob/main/Tugas_Minggu_1_Hello_World.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, World!")
print("Selamat datang di Mata Kuliah Pengantar Machine Learning!")
print("Nama: [Rizky Aditia Prinando Saputra]")
print("NIM: [221230009]")
# Out:
# Hello, World!
# Selamat datang di Mata Kuliah Pengantar Machine Learning!
# Nama: [Rizky Aditia Prinando Saputra]
# NIM: [221230009]
